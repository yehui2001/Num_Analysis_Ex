# %%
import sklearn as sk
import numpy as np
import pandas as pd
from audioop import minmax
import pickle
from sklearn.neural_network import MLPClassifier #加载neural network
from sklearn.model_selection import train_test_split #加载数据分割器

# %%
Data = pd.read_csv('breast_cancer.csv')
Data = np.array(Data) #转换成array操作，否则无法操作
P = Data[:,0:30]
T = Data[:,-1]
net = newff(minmax(P),[6,1],{'tansig','purelin'},'trainrp')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [36], line 5
#       3 P = Data[:,0:30]
#       4 T = Data[:,-1]
# ----> 5 net = newff(minmax(P),[6,1],{'tansig','purelin'},'trainrp')
#
# NameError: name 'newff' is not defined
