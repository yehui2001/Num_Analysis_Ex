# %%
import numpy as np
from sklearn.datasets import load_iris
from sklearn import tree
import random
import pydotplus
iris = load_iris() #sepal length（萼片长度）sepal width（萼片宽度）spetal length（花瓣长度）spetal width （花瓣宽度）
target = iris.target #Setosa、Versicolour、Virginica
N = 150 #训练集样本数
data = np.zeros((N,4))
target = np.zeros((N)) 

for i in range(N):
    k = random.randint(0,149)
    data[i] = iris.data[k]
    target[i] = iris.target[k]

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(data,target)
dot_data = tree.export_graphviz(clf, out_file=None)
graph = pydotplus.graph_from_dot_data(dot_data)
graph.write_pdf("mytree.pdf")

p = 0
n = 50  #测试集样本数
data_pd = np.zeros((n,4))
target_pd = clf.predict(data_pd)
target_true = np.zeros((n))

for i in range(n):
    k = random.randint(0,149)
    data_pd[i] = iris.data[k]
    target_true[i] = iris.target[k]
    if(target_true[i]==target_pd[i]):
        p = p + 1
p = p/n
print(p) #输出正确率
# Out:
# ---------------------------------------------------------------------------
# InvocationException                       Traceback (most recent call last)
# Cell In [153], line 5
#       3 dot_data = tree.export_graphviz(clf, out_file=None)
#       4 graph = pydotplus.graph_from_dot_data(dot_data)
# ----> 5 graph.write_pdf("mytree.pdf")
#       7 p = 0
#       8 n = 50  #测试集样本数
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.9/site-packages/pydotplus/graphviz.py:1810, in Dot.__init__.<locals>.<lambda>(path, f, prog)
#    1800     f.__doc__ = (
#    1801         '''Refer to the docstring accompanying the'''
#    1802         ''''create' method for more information.'''
#    1803     )
#    1805 for frmt in self.formats + ['raw']:
#    1806     self.__setattr__(
#    1807         'write_' + frmt,
#    1808         lambda path,
#    1809         f=frmt,
# -> 1810         prog=self.prog: self.write(path, format=f, prog=prog)
#    1811     )
# ...
